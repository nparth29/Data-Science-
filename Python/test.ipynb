# %%
import time
# start = time.perf_counter()  <-- REMOVED

def test_fun():
    print("do something")
    print("sleep for 2 sec")
    time.sleep(2)
    print("done with sleeping")

test_fun()
# end = time.perf_counter()    <-- REMOVED

# This next line will now cause an error!
# Out:
# do something
# sleep for 2 sec
# done with sleeping

# %%
#variance, standard deviation, range

import pandas as pd
import numpy as np

data = [10,20,30,40,50]

# Range
data_range = np.max(data) - np.min(data)

variance = np.var(data,ddof = 0)
standard_deviation = np.std(data,ddof = 0)


print("Range:",data_range)
print("Variance:",variance)
print("Standard deviation:",standard_deviation)
# Out:
# Range: 40
# Variance: 200.0
# Standard deviation: 14.142135623730951

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm, binom

# Discrete 
n,p = 10,0.5

x = np.arange(0,n+1)

pmf = binom.pmf(x,n,p)

plt.bar(x,pmf)
# Out:
# <BarContainer object of 11 artists>

# %%
# Continuos 
x = np.linspace(-3,3,100)

pdf = norm.pdf(x,0,1)

plt.plot(x,pdf)

# %%
# continuos 

from scipy.stats import uniform, norm 

# Uniform
x = np.linspace(0,1,200)

plt.plot(x,uniform.pdf(x,0,1))


# Normal distribution 

x = np.linspace(-3,3,1000)

pdf = norm.pdf(x,0,1)

plt.plot(x,pdf)

# %%
import numpy as np
data = np.random.randn(10)
data
# Out:
# array([-0.46166526, -0.33069342,  0.00423497, -0.14106785, -0.05958053,
#        -0.13014384, -1.45292621,  1.24423404, -0.05706442,  0.90815872])

# %%
import pandas as pd 

# adding a new column in existing series
series_data = pd.Series([100, 200, 300, 400], index=['a', 'b', 'c', 'd'])
df = pd.DataFrame(series_data, columns=['Values'])
print(df.head())

# adding new column : 
df["new column"] = [1, 2, 3, 4 ]

print(f"\n {df.head()}")


# access a particular column : 
print(f"\n {df["new column"]}")

# lets reset the index again without drop = True >> it will add the old index as a new column
df = df.reset_index()
print(f"\n {df}")

df["new_column_2"] = [10, 20, 30, 40]
# Out:
#    Values
# a     100
# b     200
# c     300
# d     400
#
#     Values  new column
# a     100           1
# b     200           2
# c     300           3
# d     400           4
#
#  a    1
# b    2
# c    3
# d    4
# Name: new column, dtype: int64
#
#    index  Values  new column
# 0     a     100           1
# 1     b     200           2
# 2     c     300           3
# 3     d     400           4

# %%
df.head()
# Out:
#   index  Values  new column  new_column_2
# 0     a     100           1            10
# 1     b     200           2            20
# 2     c     300           3            30
# 3     d     400           4            40

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.dtypes == "object"
# Out:
# survived       False
# pclass         False
# sex             True
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who             True
# adult_male     False
# deck           False
# embark_town     True
# alive           True
# alone          False
# dtype: bool

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.dtypes =="object"]
# Out:
# C:\Users\Naman\AppData\Local\Temp\ipykernel_4080\90102194.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.dtypes =="object"]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df[df.dtypes =="object"]
#
# File c:\Users\Naman\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4104, in DataFrame.__getitem__(self, key)
#    4102 # Do we have a (boolean) 1d indexer?
#    4103 if com.is_bool_indexer(key):
# -> 4104     return self._getitem_bool_array(key)
#    4106 # We are left with two options: a single key, and a collection of keys,
#    4107 # We interpret tuples as collections only for non-MultiIndex
#    4108 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
# Q1. How many persone of age less than 18 are there in the dataset ?
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'] < 18
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df[df.age < 18].count()
# Out:
# survived       113
# pclass         113
# sex            113
# age            113
# sibsp          113
# parch          113
# fare           113
# embarked       113
# class          113
# who            113
# adult_male     113
# deck            19
# embark_town    113
# alive          113
# alone          113
# dtype: int64

# %%
df.iloc[0]        # first row
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
df.iloc[-1, -1]
# Out:
# np.True_

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Que 1: what is the average fare paid by the people who survived ? titanic.csv

# %%
df[df['survived'] == 1]['fare'].mean()
# Out:
# np.float64(48.39540760233918)

# %%
data = {
    "Name": [f"Person{{i}}" for i in range (1,6)],
    "Age": [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data, index = [1,2,3,4,5])
df
# Out:
#         Name  Age
# 1  Person{i}   10
# 2  Person{i}   20
# 3  Person{i}   30
# 4  Person{i}   40
# 5  Person{i}   50

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 40, 50]
}
pf = pd.DataFrame(data, index = [10,20,30,40,50])

# %%
df_x_concat = pd.concat([df, pf], axis = 0, ignore_index=True)
df_x_concat
# Out:
#         Name  Age
# 0  Person{i}   10
# 1  Person{i}   20
# 2  Person{i}   30
# 3  Person{i}   40
# 4  Person{i}   50
# 5      Alice   25
# 6        Bob   30
# 7    Charlie   35
# 8      David   40
# 9        Eve   50

# %%
df_y_concat = pd.concat([df, pf], axis = 1)
df_y_concat
# Out:
#          Name   Age     Name   Age
# 1   Person{i}  10.0      NaN   NaN
# 2   Person{i}  20.0      NaN   NaN
# 3   Person{i}  30.0      NaN   NaN
# 4   Person{i}  40.0      NaN   NaN
# 5   Person{i}  50.0      NaN   NaN
# 10        NaN   NaN    Alice  25.0
# 20        NaN   NaN      Bob  30.0
# 30        NaN   NaN  Charlie  35.0
# 40        NaN   NaN    David  40.0
# 50        NaN   NaN      Eve  50.0

# %%
df_y_concat = pd.concat([df, pf], axis = 1, ignore_index=True)
df_y_concat
# Out:
#             0     1        2     3
# 1   Person{i}  10.0      NaN   NaN
# 2   Person{i}  20.0      NaN   NaN
# 3   Person{i}  30.0      NaN   NaN
# 4   Person{i}  40.0      NaN   NaN
# 5   Person{i}  50.0      NaN   NaN
# 10        NaN   NaN    Alice  25.0
# 20        NaN   NaN      Bob  30.0
# 30        NaN   NaN  Charlie  35.0
# 40        NaN   NaN    David  40.0
# 50        NaN   NaN      Eve  50.0

# %%
pd.concat([df.reset_index(drop=True), pf.reset_index(drop=True)], axis=1)
# Out:
#         Name  Age     Name  Age
# 0  Person{i}   10    Alice   25
# 1  Person{i}   20      Bob   30
# 2  Person{i}   30  Charlie   35
# 3  Person{i}   40    David   40
# 4  Person{i}   50      Eve   50

# %%
from datetime import datetime
datetime.strptime('01/15/2024', '%m/%d/%Y')
# Out:
# datetime.datetime(2024, 1, 15, 0, 0)
