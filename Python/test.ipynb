# %%
import time
# start = time.perf_counter()  <-- REMOVED

def test_fun():
    print("do something")
    print("sleep for 2 sec")
    time.sleep(2)
    print("done with sleeping")

test_fun()
# end = time.perf_counter()    <-- REMOVED

# This next line will now cause an error!
# Out:
# do something
# sleep for 2 sec
# done with sleeping

# %%
#variance, standard deviation, range

import pandas as pd
import numpy as np

data = [10,20,30,40,50]

# Range
data_range = np.max(data) - np.min(data)

variance = np.var(data,ddof = 0)
standard_deviation = np.std(data,ddof = 0)


print("Range:",data_range)
print("Variance:",variance)
print("Standard deviation:",standard_deviation)
# Out:
# Range: 40
# Variance: 200.0
# Standard deviation: 14.142135623730951

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm, binom

# Discrete 
n,p = 10,0.5

x = np.arange(0,n+1)

pmf = binom.pmf(x,n,p)

plt.bar(x,pmf)
# Out:
# <BarContainer object of 11 artists>

# %%
# Continuos 
x = np.linspace(-3,3,100)

pdf = norm.pdf(x,0,1)

plt.plot(x,pdf)

# %%
# continuos 

from scipy.stats import uniform, norm 

# Uniform
x = np.linspace(0,1,200)

plt.plot(x,uniform.pdf(x,0,1))


# Normal distribution 

x = np.linspace(-3,3,1000)

pdf = norm.pdf(x,0,1)

plt.plot(x,pdf)

# %%
import numpy as np
data = np.random.randn(10)
data
# Out:
# array([ 0.20662249, -0.84400813, -0.749464  ,  0.14004956,  1.00061955,
#         0.58901309,  1.27186775,  1.07512862,  0.11108578, -0.76942913])
